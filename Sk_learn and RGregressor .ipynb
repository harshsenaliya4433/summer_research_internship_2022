# %%
import pandas as pd
path_dried = "/content/Data Dry.xlsx"
#path_fresh = "Dataset III_Fresh Leaves.xlsx"
df_dried = pd.read_excel(path_dried)
#df_fresh = pd.read_excel(path_fresh)

# %%
df_dried.shape
# Out:
# (49, 22)

# %%
var_y = df_dried.iloc[:,0]
var_y
# Out:
# 0     42
# 1     42
# 2     41
# 3     39
# 4     22
# 5     23
# 6     23
# 7     27
# 8     29
# 9     30
# 10    31
# 11    29
# 12    30
# 13    39
# 14    35
# 15    35
# 16    33
# 17    35
# 18    33
# 19    32
# 20    32
# 21    35
# 22    35
# 23    33
# 24    33
# 25    40
# 26    37
# 27    37
# 28    35
# 29    35
# 30    44
# 31    40
# 32    35
# 33    42
# 34    39
# 35    38
# 36    43
# 37    27
# 38    26
# 39    24
# 40    25
# 41    25
# 42    27
# 43    23
# 44    26
# 45    26
# 46    24
# 47    26
# 48    27
# Name: chem_analysis-value, dtype: int64

# %%
var_x = df_dried.iloc[:,1:]
var_x
# Out:
#          692      1932      1036      1052      1164      1156       716  \
# 0   0.158602  0.396897  0.705013  0.714165  0.731468  0.735730  0.286325
# 1   0.185968  0.409268  0.601457  0.605373  0.618232  0.618937  0.318236
# 2   0.164704  0.420094  0.603253  0.606990  0.619714  0.620331  0.309623
# 3   0.154631  0.397254  0.592494  0.596313  0.606721  0.607473  0.294993
# 4   0.146520  0.495612  0.667070  0.673748  0.694199  0.695562  0.287400
# 5   0.133896  0.465873  0.643737  0.650900  0.674044  0.675256  0.253293
# 6   0.148463  0.466652  0.603300  0.608407  0.627342  0.627831  0.266749
# 7   0.129623  0.458214  0.709870  0.718318  0.735775  0.739316  0.242477
# 8   0.133041  0.500702  0.734949  0.743267  0.763543  0.766318  0.262519
# 9   0.131614  0.498479  0.730283  0.738513  0.758432  0.761141  0.257467
# 10  0.137441  0.498628  0.714308  0.723886  0.751298  0.753929  0.265934
# 11  0.139223  0.504093  0.720269  0.730328  0.759394  0.762067  0.271153
# ...

# %%
import numpy as np
varx_data = np.array(var_x)
vary_data = np.array(var_y)

# %%
varx_data
# Out:
# array([[0.15860214, 0.39689689, 0.7050127 , ..., 0.39932686, 0.50333405,
#         0.53597715],
#        [0.18596815, 0.40926778, 0.60145672, ..., 0.43741301, 0.49939877,
#         0.53501045],
#        [0.16470422, 0.42009397, 0.60325308, ..., 0.44568245, 0.49864249,
#         0.54314527],
#        ...,
#        [0.14334799, 0.56698825, 0.72433649, ..., 0.52356581, 0.55740342,
#         0.66099301],
#        [0.11118442, 0.549746  , 0.74303248, ..., 0.48242272, 0.57484351,
#         0.64448032],
#        [0.12442899, 0.5341686 , 0.73125006, ..., 0.4945054 , 0.54976905,
#         0.64573102]])

# %%
varx_data.shape
# Out:
# (49, 21)

# %%
vary_data.shape
# Out:
# (49,)

# %%
y_test = vary_data
y_train = vary_data
X_test = varx_data
X_train = varx_data

# %%
y_train
# Out:
# array([42, 42, 41, 39, 22, 23, 23, 27, 29, 30, 31, 29, 30, 39, 35, 35, 33,
#        35, 33, 32, 32, 35, 35, 33, 33, 40, 37, 37, 35, 35, 44, 40, 35, 42,
#        39, 38, 43, 27, 26, 24, 25, 25, 27, 23, 26, 26, 24, 26, 27])

# %%
y_test
# Out:
# array([42, 42, 41, 39, 22, 23, 23, 27, 29, 30, 31, 29, 30, 39, 35, 35, 33,
#        35, 33, 32, 32, 35, 35, 33, 33, 40, 37, 37, 35, 35, 44, 40, 35, 42,
#        39, 38, 43, 27, 26, 24, 25, 25, 27, 23, 26, 26, 24, 26, 27])

# %%
y_train
# Out:
# array([42, 42, 41, 39, 22, 23, 23, 27, 29, 30, 31, 29, 30, 39, 35, 35, 33,
#        35, 33, 32, 32, 35, 35, 33, 33, 40, 37, 37, 35, 35, 44, 40, 35, 42,
#        39, 38, 43, 27, 26, 24, 25, 25, 27, 23, 26, 26, 24, 26, 27])

# %%
y_test
# Out:
# array([42, 42, 41, 39, 22, 23, 23, 27, 29, 30, 31, 29, 30, 39, 35, 35, 33,
#        35, 33, 32, 32, 35, 35, 33, 33, 40, 37, 37, 35, 35, 44, 40, 35, 42,
#        39, 38, 43, 27, 26, 24, 25, 25, 27, 23, 26, 26, 24, 26, 27])

# %%
y_test.shape
# Out:
# (49,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(varx_data, vary_data, test_size=0.2, random_state=0)

# %%
y_test.reshape(-1, 1)
# Out:
# array([[35],
#        [22],
#        [37],
#        [44],
#        [35],
#        [27],
#        [39],
#        [25],
#        [27],
#        [31]])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(regressor.coef_, var_x.columns, columns=['Coefficient'])
coeff_df
# Out:
#          Coefficient
# 692      -431.888798
# 1932      -35.761321
# 1036    -2144.579761
# 1052     1474.935968
# 1164   -13425.972646
# 1156     6398.956398
# 716      -609.489662
# 404        67.827139
# 988      -682.031487
# 708       799.793407
# 1322      607.127483
# 756       607.629649
# 1772    -2629.722842
# 1708     2846.387651
# 2182    -1110.768794
# 1380      705.390341
# 2140      910.134780
# 1156.1   6398.956398
# 2052     -195.540916
# 820        66.437053
# 1884      307.984030

# %%
X_test
# Out:
# array([[0.19281788, 0.4973698 , 0.70937849, 0.71802496, 0.74173165,
#         0.74451291, 0.33841008, 0.1157601 , 0.67983902, 0.30062697,
#         0.76840198, 0.43043672, 0.60086623, 0.59319767, 0.44465937,
#         0.73614966, 0.44090644, 0.74451291, 0.47682181, 0.52098049,
#         0.60794024],
#        [0.14651967, 0.49561201, 0.66707041, 0.67374832, 0.69419926,
#         0.69556165, 0.2873999 , 0.10981107, 0.64370626, 0.23711716,
#         0.71693196, 0.42259236, 0.58832008, 0.57758432, 0.42307669,
#         0.69667606, 0.42611059, 0.69556165, 0.4619826 , 0.50642235,
#         0.59140042],
#        [0.18905097, 0.51740631, 0.75797049, 0.76585825, 0.78371279,
#         0.78675935, 0.35673145, 0.11986388, 0.73085763, 0.30696074,
#         0.80554016, 0.47760569, 0.63836115, 0.63246148, 0.47369729,
#         0.77311423, 0.4696189 , 0.78675935, 0.50817144, 0.57426484,
#         0.64153297],
#        [0.1931909 , 0.49154736, 0.695745  , 0.7033156 , 0.725683  ,
# ...

# %%
y_pred = regressor.predict(X_test)

# %%
y_test
# Out:
# array([35, 22, 37, 44, 35, 27, 39, 25, 27, 31])

# %%
y_pred
# Out:
# array([37.31988374, 31.07581345, 33.05743301, 37.15478948, 37.57097383,
#        27.61501106, 38.20941803, 25.6906405 , 35.78424416, 26.50335894])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#    Actual  Predicted
# 0      35  37.319884
# 1      22  31.075813
# 2      37  33.057433
# 3      44  37.154789
# 4      35  37.570974
# 5      27  27.615011
# 6      39  38.209418
# 7      25  25.690640
# 8      27  35.784244
# 9      31  26.503359

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.013156729200167
# Mean Squared Error: 25.56258674640815
# Root Mean Squared Error: 5.0559456826995435

# %%
y_pred.shape
# Out:
# (10,)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.4131637569695098

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
from matplotlib import pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
data = pd.read_excel(path_dried)

# %%
data.columns
# Out:
# Index(['chem_analysis-value',                   692,                  1932,
#                         1036,                  1052,                  1164,
#                         1156,                   716,                   404,
#                          988,                   708,                  1322,
#                          756,                  1772,                  1708,
#                         2182,                  1380,                  2140,
#                     '1156.1',                  2052,                   820,
#                         1884],
#       dtype='object')

# %%
data

# %%
sns.heatmap(data.corr())

# %%
data.corr()
# Out:
#                      chem_analysis-value       692      1932      1036  \
# chem_analysis-value             1.000000  0.703706  0.140083 -0.163942
# 692                             0.703706  1.000000  0.662074  0.232715
# 1932                            0.140083  0.662074  1.000000  0.646706
# 1036                           -0.163942  0.232715  0.646706  1.000000
# 1052                           -0.180338  0.202766  0.613206  0.998823
# 1164                            0.075212  0.553606  0.904418  0.890520
# 1156                            0.067248  0.542918  0.896445  0.899097
# 716                             0.671075  0.879644  0.410307  0.195952
# 404                             0.006680  0.475888  0.824955  0.755238
# 988                            -0.098806  0.337159  0.755560  0.985329
# 708                             0.722339  0.941955  0.455839  0.134382
# 1322                            0.120983  0.603634  0.932931  0.844666
# ...

# %%
# Create correlation matrix
corr_matrix = data.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 1)]

# Drop features 
data_t = data.drop(to_drop, axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """

# %%
data_t

# %%
from sklearn.model_selection import train_test_split

# %%
X = data_t.drop('chem_analysis-value', axis=1)
y = data_t['chem_analysis-value']

# %%
X.columns
# Out:
# Index([     692,     1932,     1036,     1052,     1164,     1156,      716,
#             404,      988,      708,     1322,      756,     1772,     1708,
#            2182,     1380,     2140, '1156.1',     2052,      820,     1884],
#       dtype='object')

# %%
#X_transformed["PC_1"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)


# In[363]:


from sklearn import linear_model


# In[364]:


reg = linear_model.LinearRegression()


# In[365]:


reg.fit(X_train, y_train)


# In[366]:


reg.coef_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# array([ 8.04742939e-01, -1.04640671e+02, -1.70365440e+03,  8.87174394e+02,
#        -6.26169395e+03,  3.44471166e+03,  2.56788165e+00, -2.97907206e+02,
#        -5.94115216e+02,  6.73704938e+01,  4.86364350e+02,  3.84558548e+02,
#        -1.85882822e+03,  1.75765462e+03, -3.29579091e+02, -4.31634062e+02,
#         2.28637704e+02,  3.44471166e+03, -3.74193468e+02,  1.27213636e+02,
#         9.13340210e+02])

# %%
from sklearn.metrics import mean_squared_error

# %%
y_pred = reg.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.25709122323657974

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

regr = RandomForestRegressor(n_estimators = 100, max_depth=1)
regr.fit(X_train, y_train)

y_pred = regr.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# 0.38842262247669823

# %%
#LOGARITHMIC REGRESSION

# %%
X

# %%
y_log

# %%
exp_reg_weighted = linear_model.LinearRegression()

y_log = np.log(y)
x_log = np.log(X)

X_train, X_test, y_train, y_test = train_test_split(x_log, y_log, test_size = 0.2)

exp_reg_weighted.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# LinearRegression()

# %%
y_pred = exp_reg_weighted.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5606604002114488

# %%
plt.figure(figsize=(10,10))
y_pred1 = np.exp(y_pred)
y_test1= np.exp(y_test)
plt.scatter(y_pred1, y_test1, c='crimson')

p1 = max(max(y_pred1), max(y_test1))
p2 = min(min(y_pred1), min(y_test1))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
r2_score(y_test1, y_pred1)
# Out:
# 0.5516947895657657

# %%
#EXPONENTIAL

# %%
X

# %%
y_exp2 = np.exp(y)

# %%
y_exp2
# Out:
# 0     1.739275e+18
# 1     1.739275e+18
# 2     6.398435e+17
# 3     8.659340e+16
# 4     3.584913e+09
# 5     9.744803e+09
# 6     9.744803e+09
# 7     5.320482e+11
# 8     3.931334e+12
# 9     1.068647e+13
# 10    2.904885e+13
# 11    3.931334e+12
# 12    1.068647e+13
# 13    8.659340e+16
# 14    1.586013e+15
# 15    1.586013e+15
# 16    2.146436e+14
# 17    1.586013e+15
# 18    2.146436e+14
# 19    7.896296e+13
# 20    7.896296e+13
# 21    1.586013e+15
# 22    1.586013e+15
# 23    2.146436e+14
# 24    2.146436e+14
# 25    2.353853e+17
# 26    1.171914e+16
# 27    1.171914e+16
# 28    1.586013e+15
# 29    1.586013e+15
# 30    1.285160e+19
# 31    2.353853e+17
# 32    1.586013e+15
# 33    1.739275e+18
# 34    8.659340e+16
# 35    3.185593e+16
# 36    4.727839e+18
# 37    5.320482e+11
# 38    1.957296e+11
# 39    2.648912e+10
# 40    7.200490e+10
# 41    7.200490e+10
# 42    5.320482e+11
# 43    9.744803e+09
# 44    1.957296e+11
# 45    1.957296e+11
# 46    2.648912e+10
# ...

# %%
exp_reg_weighted = linear_model.LinearRegression()

y_log2 = np.log(y)
x_exp2 = np.exp(X)
X_train, X_test, y_train, y_test = train_test_split(x_exp2, y_log, test_size = 0.2)

exp_reg_weighted.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# LinearRegression()

# %%
y_pred2 = exp_reg_weighted.predict(X_test)
y_pred2
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# array([3.33731801, 2.96068382, 3.48188802, 3.42201397, 3.54365963,
#        3.51238842, 3.48241908, 3.56145787, 3.25779061, 3.20071061])

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.28017487421526066

# %%
y_pred3= np.exp(y_pred2)

y_pred2
# Out:
# array([3.33731801, 2.96068382, 3.48188802, 3.42201397, 3.54365963,
#        3.51238842, 3.48241908, 3.56145787, 3.25779061, 3.20071061])

# %%
plt.figure(figsize=(10,10))
y_pred3= np.exp(y_pred2)
y_test3= np.exp(y_test)

plt.scatter(y_pred3, y_test3, c='crimson')

p1 = max(max(y_pred3), max(y_test3))
p2 = min(min(y_pred3), min(y_test3))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
#### PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=5)

# %%
x_transformed = pca.fit_transform(X, y=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.91323063 0.06309656 0.01364842 0.00801433 0.00120964]

# %%
X_transformed = pd.DataFrame(x_transformed, columns = ["PC_1", "PC_2", "PC_3", "PC_4", "PC_5"])

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.91323063 0.06309656 0.01364842 0.00801433 0.00120964]

# %%
pca.components_
# Out:
# array([[-0.05709073, -0.30810379, -0.1105389 , -0.10612995, -0.23373196,
#         -0.22861742, -0.03746454, -0.02081612, -0.12814917, -0.04941504,
#         -0.28945728,  0.04293836, -0.30124367, -0.27441924, -0.23583668,
#         -0.35308989, -0.23967683, -0.22861742, -0.27711885,  0.01979402,
#         -0.36312658],
#        [ 0.15270759,  0.15902609, -0.36456695, -0.38112175, -0.22974919,
#         -0.24306155,  0.09867196, -0.01711502, -0.30616189,  0.16882186,
#         -0.1801256 , -0.27147542,  0.10392375,  0.0807995 ,  0.18063453,
#         -0.02699654,  0.18265418, -0.24306155,  0.20045504, -0.33026649,
#          0.17484136],
#        [-0.38120936,  0.2837674 , -0.07976788, -0.08996305, -0.07860217,
#         -0.08380275, -0.54578499,  0.01351344, -0.04360308, -0.63421664,
#         -0.07834925,  0.02834505,  0.0771233 ,  0.0334591 ,  0.00165004,
#         -0.02582817,  0.03198263, -0.08380275,  0.04916973,  0.05288782,
#          0.12791491],
# ...

# %%
###Logisitc Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, y_train)
y_pred = logisticRegr.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,

# %%
r2_score(y_test, y_pred)
# Out:
# -0.17998163452708904

# %%
from sklearn.tree import DecisionTreeRegressor

#create the regression tree with a max depth of 5
reg_tree = DecisionTreeRegressor(random_state = 0,
                                max_depth = 5)

#fit the regression tree
reg_tree.fit(X_train, y_train)

#check the score on the test set
reg_tree.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   FutureWarning,
# -0.10679522497704319
